# %%
import requests as requests
from citipy import citipy
from config import weather_api_key
from config import g_key
import requests
weather_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = weather_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Right Now": city_description,
                          "Country": city_country,
                          "Date": city_date})


# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gat
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | necochea
# Processing Record 4 of Set 1 | lorengau
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | sitka
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | beringovskiy
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | provideniya
# Processing Record 13 of Set 1 | khonsa
# Processing Record 14 of Set 1 | tefe
# Processing Record 15 of Set 1 | roros
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | mahebourg
# Processing Record 18 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 1 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | santiago
# Processing Record 22 of Set 1 | northam
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | atar
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | jinchang
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | lebu
# Processing Record 30 of Set 1 | torbay
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | dauphin
# Processing Record 33 of Set 1 | chinsali
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | dzhebariki-khaya
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | harper
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | krasnyy chikoy
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 1 | mecca
# Processing Record 44 of Set 1 | kimbe
# Processing Record 45 of Set 1 | sechura
# Processing Record 46 of Set 1 | upata
# Processing Record 47 of Set 1 | ushuaia
# Processing Record 48 of Set 1 | hamilton
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | saint george
# Processing Record 1 of Set 2 | fortuna
# Processing Record 2 of Set 2 | adeje
# Processing Record 3 of Set 2 | boissevain
# Processing Record 4 of Set 2 | sahrak
# City not found. Skipping...
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | acajutla
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | khani
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | jumla
# Processing Record 11 of Set 2 | sao filipe
# Processing Record 12 of Set 2 | toora-khem
# Processing Record 13 of Set 2 | cherskiy
# Processing Record 14 of Set 2 | karratha
# Processing Record 15 of Set 2 | nome
# Processing Record 16 of Set 2 | riyadh
# Processing Record 17 of Set 2 | severnoye
# Processing Record 18 of Set 2 | lagoa
# Processing Record 19 of Set 2 | talnakh
# Processing Record 20 of Set 2 | chokurdakh
# Processing Record 21 of Set 2 | doba
# Processing Record 22 of Set 2 | kobojango
# City not found. Skipping...
# Processing Record 23 of Set 2 | sorland
# Processing Record 24 of Set 2 | clyde river
# Processing Record 25 of Set 2 | makakilo city
# Processing Record 26 of Set 2 | asau
# Processing Record 27 of Set 2 | pisco
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 2 | kruisfontein
# Processing Record 31 of Set 2 | santa fe
# Processing Record 32 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 2 | katherine
# Processing Record 34 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 2 | cabra
# Processing Record 36 of Set 2 | ribeira grande
# Processing Record 37 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 2 | auki
# Processing Record 39 of Set 2 | palmer
# Processing Record 40 of Set 2 | ilulissat
# Processing Record 41 of Set 2 | kavaratti
# Processing Record 42 of Set 2 | luderitz
# Processing Record 43 of Set 2 | amga
# Processing Record 44 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 2 | faya
# Processing Record 46 of Set 2 | pevek
# Processing Record 47 of Set 2 | atambua
# Processing Record 48 of Set 2 | panaba
# Processing Record 49 of Set 2 | san carlos
# Processing Record 50 of Set 2 | mount gambier
# Processing Record 1 of Set 3 | nikolskoye
# Processing Record 2 of Set 3 | riviere-au-renard
# Processing Record 3 of Set 3 | kichera
# Processing Record 4 of Set 3 | ostrovnoy
# Processing Record 5 of Set 3 | port hardy
# Processing Record 6 of Set 3 | amberley
# Processing Record 7 of Set 3 | paita
# Processing Record 8 of Set 3 | hilo
# Processing Record 9 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 3 | chulym
# Processing Record 12 of Set 3 | ancud
# Processing Record 13 of Set 3 | carson city
# Processing Record 14 of Set 3 | asfi
# Processing Record 15 of Set 3 | georgetown
# Processing Record 16 of Set 3 | hami
# Processing Record 17 of Set 3 | yellowknife
# Processing Record 18 of Set 3 | toppenish
# Processing Record 19 of Set 3 | polunochnoye
# Processing Record 20 of Set 3 | dikson
# Processing Record 21 of Set 3 | kurilsk
# Processing Record 22 of Set 3 | santa cruz
# Processing Record 23 of Set 3 | kaitangata
# Processing Record 24 of Set 3 | rocha
# Processing Record 25 of Set 3 | bengkalis
# City not found. Skipping...
# Processing Record 26 of Set 3 | acarau
# Processing Record 27 of Set 3 | bosaso
# Processing Record 28 of Set 3 | sarakhs
# Processing Record 29 of Set 3 | san isidro
# Processing Record 30 of Set 3 | skibbereen
# Processing Record 31 of Set 3 | korla
# Processing Record 32 of Set 3 | oussouye
# Processing Record 33 of Set 3 | whitecourt
# Processing Record 34 of Set 3 | airai
# Processing Record 35 of Set 3 | amazar
# Processing Record 36 of Set 3 | mackay
# Processing Record 37 of Set 3 | san patricio
# Processing Record 38 of Set 3 | iquique
# Processing Record 39 of Set 3 | iquitos
# Processing Record 40 of Set 3 | berlevag
# Processing Record 41 of Set 3 | yulara
# Processing Record 42 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 3 | arlit
# Processing Record 44 of Set 3 | wahpeton
# Processing Record 45 of Set 3 | college
# Processing Record 46 of Set 3 | narsaq
# Processing Record 47 of Set 3 | avarua
# Processing Record 48 of Set 3 | khatanga
# Processing Record 49 of Set 3 | honghu
# Processing Record 50 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 1 of Set 4 | katsuura
# Processing Record 2 of Set 4 | tasiilaq
# Processing Record 3 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 4 | rochegda
# Processing Record 5 of Set 4 | bambous virieux
# Processing Record 6 of Set 4 | morant bay
# Processing Record 7 of Set 4 | aktau
# Processing Record 8 of Set 4 | ranau
# Processing Record 9 of Set 4 | kysyl-syr
# Processing Record 10 of Set 4 | hermanus
# Processing Record 11 of Set 4 | qaanaaq
# Processing Record 12 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 4 | port keats
# Processing Record 14 of Set 4 | vetluzhskiy
# Processing Record 15 of Set 4 | la ronge
# Processing Record 16 of Set 4 | yvetot
# Processing Record 17 of Set 4 | seoul
# Processing Record 18 of Set 4 | tuktoyaktuk
# Processing Record 19 of Set 4 | muros
# Processing Record 20 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 4 | mar del plata
# Processing Record 22 of Set 4 | meulaboh
# Processing Record 23 of Set 4 | takoradi
# Processing Record 24 of Set 4 | bathsheba
# Processing Record 25 of Set 4 | hongjiang
# Processing Record 26 of Set 4 | estacion coahuila
# Processing Record 27 of Set 4 | port elizabeth
# Processing Record 28 of Set 4 | tancitaro
# Processing Record 29 of Set 4 | khanino
# Processing Record 30 of Set 4 | nemuro
# Processing Record 31 of Set 4 | muroto
# Processing Record 32 of Set 4 | vardo
# Processing Record 33 of Set 4 | namatanai
# Processing Record 34 of Set 4 | komsomolskiy
# Processing Record 35 of Set 4 | bengkulu
# Processing Record 36 of Set 4 | cabedelo
# Processing Record 37 of Set 4 | peruibe
# Processing Record 38 of Set 4 | jiaojiang
# Processing Record 39 of Set 4 | yamada
# Processing Record 40 of Set 4 | tuatapere
# Processing Record 41 of Set 4 | cabo san lucas
# Processing Record 42 of Set 4 | juneau
# Processing Record 43 of Set 4 | odawara
# Processing Record 44 of Set 4 | longyearbyen
# Processing Record 45 of Set 4 | luwuk
# Processing Record 46 of Set 4 | wad madani
# Processing Record 47 of Set 4 | capreol
# Processing Record 48 of Set 4 | kassala
# Processing Record 49 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 4 | podor
# Processing Record 1 of Set 5 | udachnyy
# Processing Record 2 of Set 5 | norman wells
# Processing Record 3 of Set 5 | karasjok
# Processing Record 4 of Set 5 | san ramon de la nueva oran
# Processing Record 5 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 5 | victoria
# Processing Record 8 of Set 5 | saint-francois
# Processing Record 9 of Set 5 | wanning
# Processing Record 10 of Set 5 | ketchikan
# Processing Record 11 of Set 5 | nelson bay
# Processing Record 12 of Set 5 | miandrivazo
# Processing Record 13 of Set 5 | hambantota
# Processing Record 14 of Set 5 | constitucion
# Processing Record 15 of Set 5 | viedma
# Processing Record 16 of Set 5 | oranjemund
# Processing Record 17 of Set 5 | lavrentiya
# Processing Record 18 of Set 5 | bethel
# Processing Record 19 of Set 5 | vao
# Processing Record 20 of Set 5 | nador
# Processing Record 21 of Set 5 | castro
# Processing Record 22 of Set 5 | sao joao da barra
# Processing Record 23 of Set 5 | ahmadpur
# Processing Record 24 of Set 5 | port blair
# Processing Record 25 of Set 5 | banda aceh
# Processing Record 26 of Set 5 | pedernales
# Processing Record 27 of Set 5 | chara
# Processing Record 28 of Set 5 | victor harbor
# Processing Record 29 of Set 5 | broome
# Processing Record 30 of Set 5 | carmen
# Processing Record 31 of Set 5 | scarborough
# Processing Record 32 of Set 5 | brae
# Processing Record 33 of Set 5 | teknaf
# Processing Record 34 of Set 5 | yertsevo
# Processing Record 35 of Set 5 | sinegorye
# Processing Record 36 of Set 5 | saint-leu
# Processing Record 37 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 5 | chuy
# Processing Record 39 of Set 5 | elizabeth city
# Processing Record 40 of Set 5 | san marcos
# Processing Record 41 of Set 5 | banjar
# Processing Record 42 of Set 5 | tautira
# Processing Record 43 of Set 5 | labuhan
# Processing Record 44 of Set 5 | shache
# Processing Record 45 of Set 5 | hirara
# Processing Record 46 of Set 5 | severo-kurilsk
# Processing Record 47 of Set 5 | upernavik
# Processing Record 48 of Set 5 | matara
# Processing Record 49 of Set 5 | poya
# Processing Record 50 of Set 5 | ariquemes
# Processing Record 1 of Set 6 | nurota
# Processing Record 2 of Set 6 | esperance
# Processing Record 3 of Set 6 | kiboga
# Processing Record 4 of Set 6 | dawson creek
# Processing Record 5 of Set 6 | hovd
# Processing Record 6 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 6 | krutinka
# Processing Record 8 of Set 6 | bystryy istok
# Processing Record 9 of Set 6 | hithadhoo
# Processing Record 10 of Set 6 | ulladulla
# Processing Record 11 of Set 6 | madison
# Processing Record 12 of Set 6 | wanaka
# Processing Record 13 of Set 6 | faanui
# Processing Record 14 of Set 6 | sorong
# Processing Record 15 of Set 6 | vanavara
# Processing Record 16 of Set 6 | humaita
# Processing Record 17 of Set 6 | macae
# Processing Record 18 of Set 6 | el sauzal
# Processing Record 19 of Set 6 | starogard gdanski
# Processing Record 20 of Set 6 | noumea
# Processing Record 21 of Set 6 | harindanga
# Processing Record 22 of Set 6 | chapais
# Processing Record 23 of Set 6 | kant
# Processing Record 24 of Set 6 | ambon
# Processing Record 25 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 26 of Set 6 | maridi
# Processing Record 27 of Set 6 | clarence town
# Processing Record 28 of Set 6 | turukhansk
# Processing Record 29 of Set 6 | baglan
# Processing Record 30 of Set 6 | nanortalik
# Processing Record 31 of Set 6 | los llanos de aridane
# Processing Record 32 of Set 6 | geraldton
# Processing Record 33 of Set 6 | ambilobe
# Processing Record 34 of Set 6 | ponta do sol
# Processing Record 35 of Set 6 | cidreira
# Processing Record 36 of Set 6 | fare
# Processing Record 37 of Set 6 | east london
# Processing Record 38 of Set 6 | winnemucca
# Processing Record 39 of Set 6 | port-cartier
# Processing Record 40 of Set 6 | marawi
# Processing Record 41 of Set 6 | vila do maio
# Processing Record 42 of Set 6 | isoka
# Processing Record 43 of Set 6 | san quintin
# Processing Record 44 of Set 6 | pacific grove
# Processing Record 45 of Set 6 | port hedland
# Processing Record 46 of Set 6 | bredasdorp
# Processing Record 47 of Set 6 | sijunjung
# Processing Record 48 of Set 6 | semey
# Processing Record 49 of Set 6 | saint albans
# Processing Record 50 of Set 6 | tiksi
# Processing Record 1 of Set 7 | tura
# Processing Record 2 of Set 7 | caravelas
# Processing Record 3 of Set 7 | nesebar
# Processing Record 4 of Set 7 | hofn
# Processing Record 5 of Set 7 | dunedin
# Processing Record 6 of Set 7 | minjur
# Processing Record 7 of Set 7 | dalaba
# Processing Record 8 of Set 7 | kedougou
# Processing Record 9 of Set 7 | kisangani
# Processing Record 10 of Set 7 | egvekinot
# Processing Record 11 of Set 7 | xinxiang
# Processing Record 12 of Set 7 | north bend
# Processing Record 13 of Set 7 | sao felix do xingu
# Processing Record 14 of Set 7 | iqaluit
# Processing Record 15 of Set 7 | grindavik
# Processing Record 16 of Set 7 | serafimovich
# Processing Record 17 of Set 7 | basco
# Processing Record 18 of Set 7 | sabha
# Processing Record 19 of Set 7 | krumbach
# Processing Record 20 of Set 7 | puerto colombia
# Processing Record 21 of Set 7 | gornyy
# Processing Record 22 of Set 7 | kayes
# Processing Record 23 of Set 7 | pangnirtung
# Processing Record 24 of Set 7 | carutapera
# Processing Record 25 of Set 7 | codrington
# Processing Record 26 of Set 7 | masunga
# Processing Record 27 of Set 7 | ciudad bolivar
# Processing Record 28 of Set 7 | qom
# Processing Record 29 of Set 7 | zlobin
# Processing Record 30 of Set 7 | makasar
# Processing Record 31 of Set 7 | taperoa
# Processing Record 32 of Set 7 | luau
# Processing Record 33 of Set 7 | meadow lake
# Processing Record 34 of Set 7 | wana
# Processing Record 35 of Set 7 | misratah
# Processing Record 36 of Set 7 | san cristobal
# Processing Record 37 of Set 7 | leningradskiy
# Processing Record 38 of Set 7 | saint anthony
# Processing Record 39 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 40 of Set 7 | guerrero negro
# Processing Record 41 of Set 7 | flinders
# Processing Record 42 of Set 7 | mahibadhoo
# Processing Record 43 of Set 7 | daru
# Processing Record 44 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 45 of Set 7 | gejiu
# Processing Record 46 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 7 | half moon bay
# Processing Record 48 of Set 7 | hasaki
# Processing Record 49 of Set 7 | tumut
# Processing Record 50 of Set 7 | passos
# Processing Record 1 of Set 8 | lufilufi
# Processing Record 2 of Set 8 | casteltermini
# Processing Record 3 of Set 8 | bilma
# Processing Record 4 of Set 8 | saskylakh
# Processing Record 5 of Set 8 | sistranda
# Processing Record 6 of Set 8 | goderich
# Processing Record 7 of Set 8 | veraval
# Processing Record 8 of Set 8 | quime
# Processing Record 9 of Set 8 | namie
# Processing Record 10 of Set 8 | ippy
# Processing Record 11 of Set 8 | micheweni
# Processing Record 12 of Set 8 | imbituba
# Processing Record 13 of Set 8 | aklavik
# Processing Record 14 of Set 8 | boyuibe
# Processing Record 15 of Set 8 | maniitsoq
# Processing Record 16 of Set 8 | sundsvall
# Processing Record 17 of Set 8 | hailun
# Processing Record 18 of Set 8 | sadiqabad
# Processing Record 19 of Set 8 | cherkasskoye
# Processing Record 20 of Set 8 | mutis
# Processing Record 21 of Set 8 | el faiyum
# City not found. Skipping...
# Processing Record 22 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 8 | zhanaozen
# Processing Record 24 of Set 8 | barvinkove
# Processing Record 25 of Set 8 | xuddur
# Processing Record 26 of Set 8 | evensk
# Processing Record 27 of Set 8 | tual
# Processing Record 28 of Set 8 | ginda
# Processing Record 29 of Set 8 | niquero
# Processing Record 30 of Set 8 | palaifiton
# City not found. Skipping...
# Processing Record 31 of Set 8 | klaksvik
# Processing Record 32 of Set 8 | thunder bay
# Processing Record 33 of Set 8 | portland
# Processing Record 34 of Set 8 | vestmannaeyjar
# Processing Record 35 of Set 8 | opunake
# Processing Record 36 of Set 8 | vaitape
# Processing Record 37 of Set 8 | touros
# Processing Record 38 of Set 8 | znamenskoye
# Processing Record 39 of Set 8 | ayr
# Processing Record 40 of Set 8 | mandalgovi
# Processing Record 41 of Set 8 | saldanha
# Processing Record 42 of Set 8 | omboue
# Processing Record 43 of Set 8 | ust-nera
# Processing Record 44 of Set 8 | houma
# Processing Record 45 of Set 8 | port macquarie
# Processing Record 46 of Set 8 | zhetybay
# City not found. Skipping...
# Processing Record 47 of Set 8 | cayenne
# Processing Record 48 of Set 8 | kidal
# Processing Record 49 of Set 8 | shingu
# Processing Record 50 of Set 8 | montrose
# Processing Record 1 of Set 9 | asayita
# City not found. Skipping...
# Processing Record 2 of Set 9 | ambovombe
# Processing Record 3 of Set 9 | nuuk
# Processing Record 4 of Set 9 | vanimo
# Processing Record 5 of Set 9 | vila
# Processing Record 6 of Set 9 | lamu
# Processing Record 7 of Set 9 | olinda
# Processing Record 8 of Set 9 | russell
# Processing Record 9 of Set 9 | erzin
# Processing Record 10 of Set 9 | taltal
# Processing Record 11 of Set 9 | nantucket
# Processing Record 12 of Set 9 | lake city
# Processing Record 13 of Set 9 | bandarbeyla
# Processing Record 14 of Set 9 | vanino
# Processing Record 15 of Set 9 | kieta
# Processing Record 16 of Set 9 | marzuq
# Processing Record 17 of Set 9 | bud
# Processing Record 18 of Set 9 | youghal
# Processing Record 19 of Set 9 | copiapo
# Processing Record 20 of Set 9 | lavras
# Processing Record 21 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 22 of Set 9 | pangai
# Processing Record 23 of Set 9 | opuwo
# Processing Record 24 of Set 9 | svetlogorsk
# Processing Record 25 of Set 9 | sambava
# Processing Record 26 of Set 9 | kenai
# Processing Record 27 of Set 9 | ouango
# Processing Record 28 of Set 9 | alice springs
# Processing Record 29 of Set 9 | anadyr
# Processing Record 30 of Set 9 | gebze
# Processing Record 31 of Set 9 | high level
# Processing Record 32 of Set 9 | fairbanks
# Processing Record 33 of Set 9 | pechenga
# Processing Record 34 of Set 9 | saint-pierre
# Processing Record 35 of Set 9 | kahului
# Processing Record 36 of Set 9 | nishihara
# Processing Record 37 of Set 9 | kupang
# Processing Record 38 of Set 9 | sao jose da coroa grande
# Processing Record 39 of Set 9 | todos santos
# Processing Record 40 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 41 of Set 9 | fallon
# Processing Record 42 of Set 9 | charagua
# Processing Record 43 of Set 9 | alta floresta
# Processing Record 44 of Set 9 | pitlochry
# Processing Record 45 of Set 9 | vila franca do campo
# Processing Record 46 of Set 9 | maxixe
# Processing Record 47 of Set 9 | quatre cocos
# Processing Record 48 of Set 9 | finschhafen
# Processing Record 49 of Set 9 | salta
# Processing Record 50 of Set 9 | inhambane
# Processing Record 1 of Set 10 | kirakira
# Processing Record 2 of Set 10 | nagykanizsa
# Processing Record 3 of Set 10 | santa lucia
# Processing Record 4 of Set 10 | gerash
# Processing Record 5 of Set 10 | immokalee
# Processing Record 6 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 7 of Set 10 | ust-ilimsk
# Processing Record 8 of Set 10 | hameenlinna
# Processing Record 9 of Set 10 | sur
# Processing Record 10 of Set 10 | namibe
# Processing Record 11 of Set 10 | svetlyy
# Processing Record 12 of Set 10 | avera
# Processing Record 13 of Set 10 | sakakah
# Processing Record 14 of Set 10 | havre-saint-pierre
# Processing Record 15 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 16 of Set 10 | deputatskiy
# Processing Record 17 of Set 10 | salalah
# Processing Record 18 of Set 10 | goure
# Processing Record 19 of Set 10 | gari
# Processing Record 20 of Set 10 | lompoc
# Processing Record 21 of Set 10 | dingle
# Processing Record 22 of Set 10 | pimentel
# Processing Record 23 of Set 10 | narasannapeta
# Processing Record 24 of Set 10 | camacari
# Processing Record 25 of Set 10 | fort nelson
# Processing Record 26 of Set 10 | mobaye
# Processing Record 27 of Set 10 | cockburn town
# Processing Record 28 of Set 10 | lake charles
# Processing Record 29 of Set 10 | mazagao
# Processing Record 30 of Set 10 | cap malheureux
# Processing Record 31 of Set 10 | salvacion
# Processing Record 32 of Set 10 | honningsvag
# Processing Record 33 of Set 10 | ambulu
# Processing Record 34 of Set 10 | paamiut
# Processing Record 35 of Set 10 | kibondo
# Processing Record 36 of Set 10 | laguna
# Processing Record 37 of Set 10 | el seibo
# Processing Record 38 of Set 10 | yenagoa
# Processing Record 39 of Set 10 | parras
# City not found. Skipping...
# Processing Record 40 of Set 10 | kot samaba
# Processing Record 41 of Set 10 | sinnamary
# Processing Record 42 of Set 10 | ferrandina
# Processing Record 43 of Set 10 | chimore
# Processing Record 44 of Set 10 | usvyaty
# Processing Record 45 of Set 10 | verkhnevilyuysk
# Processing Record 46 of Set 10 | walvis bay
# Processing Record 47 of Set 10 | baculin
# Processing Record 48 of Set 10 | lebanon
# Processing Record 49 of Set 10 | beloha
# Processing Record 50 of Set 10 | erenhot
# Processing Record 1 of Set 11 | srednekolymsk
# Processing Record 2 of Set 11 | bakau
# Processing Record 3 of Set 11 | bulaevo
# Processing Record 4 of Set 11 | pietarsaari
# Processing Record 5 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 11 | dejen
# Processing Record 7 of Set 11 | padang
# Processing Record 8 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 9 of Set 11 | trenggalek
# Processing Record 10 of Set 11 | junagadh
# Processing Record 11 of Set 11 | bacalar
# Processing Record 12 of Set 11 | bani walid
# Processing Record 13 of Set 11 | uyemskiy
# Processing Record 14 of Set 11 | orshanka
# Processing Record 15 of Set 11 | altay
# Processing Record 16 of Set 11 | kijang
# Processing Record 17 of Set 11 | road town
# Processing Record 18 of Set 11 | gao
# Processing Record 19 of Set 11 | obihiro
# Processing Record 20 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 11 | port-gentil
# Processing Record 22 of Set 11 | ugoofaaru
# Processing Record 23 of Set 11 | ucluelet
# Processing Record 24 of Set 11 | richards bay
# Processing Record 25 of Set 11 | namtsy
# Processing Record 26 of Set 11 | tumen
# Processing Record 27 of Set 11 | sawakin
# Processing Record 28 of Set 11 | derzhavinsk
# Processing Record 29 of Set 11 | espirito santo do pinhal
# Processing Record 30 of Set 11 | tukrah
# Processing Record 31 of Set 11 | santa maria
# Processing Record 32 of Set 11 | hot springs
# Processing Record 33 of Set 11 | sobolevo
# Processing Record 34 of Set 11 | nogliki
# Processing Record 35 of Set 11 | puerto escondido
# Processing Record 36 of Set 11 | say
# Processing Record 37 of Set 11 | chegdomyn
# Processing Record 38 of Set 11 | prachuap khiri khan
# Processing Record 39 of Set 11 | helong
# Processing Record 40 of Set 11 | wajir
# Processing Record 41 of Set 11 | tondela
# Processing Record 42 of Set 11 | mandera
# Processing Record 43 of Set 11 | labytnangi
# Processing Record 44 of Set 11 | mount isa
# Processing Record 45 of Set 11 | vengerovo
# Processing Record 46 of Set 11 | nadym
# Processing Record 47 of Set 11 | coihaique
# Processing Record 48 of Set 11 | thinadhoo
# Processing Record 49 of Set 11 | jieshi
# Processing Record 50 of Set 11 | cognac
# Processing Record 1 of Set 12 | olafsvik
# Processing Record 2 of Set 12 | klyuchi
# Processing Record 3 of Set 12 | huarmey
# Processing Record 4 of Set 12 | aranos
# Processing Record 5 of Set 12 | kolobrzeg
# Processing Record 6 of Set 12 | bambanglipuro
# Processing Record 7 of Set 12 | san policarpo
# Processing Record 8 of Set 12 | salinas
# Processing Record 9 of Set 12 | aromashevo
# Processing Record 10 of Set 12 | kataysk
# Processing Record 11 of Set 12 | yuzhno-kurilsk
# Processing Record 12 of Set 12 | talas
# Processing Record 13 of Set 12 | kalaleh
# Processing Record 14 of Set 12 | qaqortoq
# Processing Record 15 of Set 12 | lock haven
# Processing Record 16 of Set 12 | verkhoyansk
# Processing Record 17 of Set 12 | sarandi
# Processing Record 18 of Set 12 | mahanoro
# Processing Record 19 of Set 12 | savyntsi
# Processing Record 20 of Set 12 | bayan
# Processing Record 21 of Set 12 | tanshui
# City not found. Skipping...
# Processing Record 22 of Set 12 | bungu
# Processing Record 23 of Set 12 | porterville
# Processing Record 24 of Set 12 | ayer itam
# City not found. Skipping...
# Processing Record 25 of Set 12 | roald
# Processing Record 26 of Set 12 | ayan
# Processing Record 27 of Set 12 | pekalongan
# Processing Record 28 of Set 12 | suzuka
# Processing Record 29 of Set 12 | rock sound
# Processing Record 30 of Set 12 | sigli
# Processing Record 31 of Set 12 | buluang
# Processing Record 32 of Set 12 | chase
# Processing Record 33 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 12 | chandler
# Processing Record 35 of Set 12 | denpasar
# Processing Record 36 of Set 12 | kamariotissa
# Processing Record 37 of Set 12 | bubaque
# Processing Record 38 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 39 of Set 12 | whitehorse
# Processing Record 40 of Set 12 | ferme-neuve
# Processing Record 41 of Set 12 | biala podlaska
# Processing Record 42 of Set 12 | jalu
# Processing Record 43 of Set 12 | kiunga
# Processing Record 44 of Set 12 | litoral del san juan
# City not found. Skipping...
# Processing Record 45 of Set 12 | te anau
# Processing Record 46 of Set 12 | shahreza
# Processing Record 47 of Set 12 | byron bay
# Processing Record 48 of Set 12 | zhigansk
# Processing Record 49 of Set 12 | yeppoon
# Processing Record 50 of Set 12 | tsumeb
# Processing Record 1 of Set 13 | oranjestad
# Processing Record 2 of Set 13 | rotnes
# Processing Record 3 of Set 13 | fukue
# Processing Record 4 of Set 13 | buraydah
# Processing Record 5 of Set 13 | mangan
# Processing Record 6 of Set 13 | kaili
# Processing Record 7 of Set 13 | eyl
# Processing Record 8 of Set 13 | westport
# Processing Record 9 of Set 13 | hualmay
# Processing Record 10 of Set 13 | aykhal
# Processing Record 11 of Set 13 | poum
# Processing Record 12 of Set 13 | ipixuna
# Processing Record 13 of Set 13 | vallenar
# Processing Record 14 of Set 13 | keetmanshoop
# Processing Record 15 of Set 13 | kuznechnoye
# Processing Record 16 of Set 13 | dipkarpaz
# City not found. Skipping...
# Processing Record 17 of Set 13 | kalamazoo
# Processing Record 18 of Set 13 | sterling
# Processing Record 19 of Set 13 | kambove
# Processing Record 20 of Set 13 | comodoro rivadavia
# Processing Record 21 of Set 13 | lerwick
# Processing Record 22 of Set 13 | polyarnyy
# Processing Record 23 of Set 13 | vanderhoof
# Processing Record 24 of Set 13 | methoni
# Processing Record 25 of Set 13 | margate
# Processing Record 26 of Set 13 | madhupur
# Processing Record 27 of Set 13 | oksfjord
# Processing Record 28 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 13 | praia
# Processing Record 30 of Set 13 | port lincoln
# Processing Record 31 of Set 13 | belaya gora
# Processing Record 32 of Set 13 | honiara
# Processing Record 33 of Set 13 | polewali
# Processing Record 34 of Set 13 | itarema
# Processing Record 35 of Set 13 | croydon
# Processing Record 36 of Set 13 | nargana
# Processing Record 37 of Set 13 | ballina
# Processing Record 38 of Set 13 | sampit
# Processing Record 39 of Set 13 | eureka
# Processing Record 40 of Set 13 | visby
# Processing Record 41 of Set 13 | roma
# Processing Record 42 of Set 13 | lodja
# Processing Record 43 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 44 of Set 13 | kostelec nad labem
# Processing Record 45 of Set 13 | pauini
# Processing Record 46 of Set 13 | yar-sale
# Processing Record 47 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 13 | kaka
# Processing Record 49 of Set 13 | lac du bonnet
# Processing Record 50 of Set 13 | oyem
# Processing Record 1 of Set 14 | tevaitoa
# Processing Record 2 of Set 14 | rebrikha
# Processing Record 3 of Set 14 | ibitinga
# Processing Record 4 of Set 14 | naze
# Processing Record 5 of Set 14 | demyansk
# Processing Record 6 of Set 14 | vestmanna
# Processing Record 7 of Set 14 | san antonio
# Processing Record 8 of Set 14 | tandil
# Processing Record 9 of Set 14 | santa catalina
# Processing Record 10 of Set 14 | kapiri mposhi
# Processing Record 11 of Set 14 | grand gaube
# Processing Record 12 of Set 14 | kaliningrad
# Processing Record 13 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 14 of Set 14 | waipawa
# Processing Record 15 of Set 14 | guaraniacu
# Processing Record 16 of Set 14 | mbekenyera
# Processing Record 17 of Set 14 | jaguarao
# Processing Record 18 of Set 14 | pemangkat
# Processing Record 19 of Set 14 | smithers
# Processing Record 20 of Set 14 | camacha
# Processing Record 21 of Set 14 | inuvik
# Processing Record 22 of Set 14 | san joaquin
# Processing Record 23 of Set 14 | saint-joseph
# Processing Record 24 of Set 14 | taonan
# Processing Record 25 of Set 14 | piacabucu
# Processing Record 26 of Set 14 | zhangjiakou
# Processing Record 27 of Set 14 | alofi
# Processing Record 28 of Set 14 | peterhead
# Processing Record 29 of Set 14 | pasighat
# Processing Record 30 of Set 14 | abatskoye
# Processing Record 31 of Set 14 | carballo
# Processing Record 32 of Set 14 | pucallpa
# Processing Record 33 of Set 14 | bardiyah
# Processing Record 34 of Set 14 | oak ridge
# Processing Record 35 of Set 14 | benito juarez
# Processing Record 36 of Set 14 | santarem
# Processing Record 37 of Set 14 | carlisle
# Processing Record 38 of Set 14 | ekimchan
# Processing Record 39 of Set 14 | balangiga
# Processing Record 40 of Set 14 | lagos
# Processing Record 41 of Set 14 | leshukonskoye
# Processing Record 42 of Set 14 | teguldet
# Processing Record 43 of Set 14 | brighton
# Processing Record 44 of Set 14 | zarubino
# Processing Record 45 of Set 14 | vonnu
# City not found. Skipping...
# Processing Record 46 of Set 14 | roebourne
# Processing Record 47 of Set 14 | esna
# Processing Record 48 of Set 14 | dumas
# Processing Record 49 of Set 14 | tchaourou
# Processing Record 50 of Set 14 | rayong
# Processing Record 1 of Set 15 | prado
# Processing Record 2 of Set 15 | kalmunai
# Processing Record 3 of Set 15 | weinan
# Processing Record 4 of Set 15 | awjilah
# Processing Record 5 of Set 15 | shaunavon
# Processing Record 6 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 15 | nouadhibou
# Processing Record 8 of Set 15 | coari
# Processing Record 9 of Set 15 | ridgecrest
# Processing Record 10 of Set 15 | santiago del estero
# Processing Record 11 of Set 15 | lazaro cardenas
# Processing Record 12 of Set 15 | guicheng
# City not found. Skipping...
# Processing Record 13 of Set 15 | amapa
# Processing Record 14 of Set 15 | waiuku
# Processing Record 15 of Set 15 | rahatgarh
# Processing Record 16 of Set 15 | chervone
# Processing Record 17 of Set 15 | panukulan
# Processing Record 18 of Set 15 | stokmarknes
# Processing Record 19 of Set 15 | cassilandia
# Processing Record 20 of Set 15 | mogadishu
# Processing Record 21 of Set 15 | shebunino
# Processing Record 22 of Set 15 | hanmer springs
# Processing Record 23 of Set 15 | adrar
# Processing Record 24 of Set 15 | agadez
# Processing Record 25 of Set 15 | monrovia
# Processing Record 26 of Set 15 | manokwari
# Processing Record 27 of Set 15 | aksarayskiy
# Processing Record 28 of Set 15 | manono
# Processing Record 29 of Set 15 | songjianghe
# Processing Record 30 of Set 15 | pointe michel
# Processing Record 31 of Set 15 | baruun-urt
# Processing Record 32 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 33 of Set 15 | bratsk
# Processing Record 34 of Set 15 | petropavlovka
# Processing Record 35 of Set 15 | aasiaat
# Processing Record 36 of Set 15 | greymouth
# Processing Record 37 of Set 15 | wilmington
# Processing Record 38 of Set 15 | beruni
# City not found. Skipping...
# Processing Record 39 of Set 15 | pontianak
# Processing Record 40 of Set 15 | nguruka
# Processing Record 41 of Set 15 | north myrtle beach
# Processing Record 42 of Set 15 | muncar
# Processing Record 43 of Set 15 | urucui
# Processing Record 44 of Set 15 | haapiti
# Processing Record 45 of Set 15 | bilibino
# Processing Record 46 of Set 15 | sarkand
# Processing Record 47 of Set 15 | mangrol
# Processing Record 48 of Set 15 | lincoln
# Processing Record 49 of Set 15 | zhicheng
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Gat  31.6100   34.7642     51.40       100          54
# 1       Rikitea -23.1203 -134.9692     77.83        66          73
# 2      Necochea -38.5473  -58.7368     62.04        53          63
# 3      Lorengau  -2.0226  147.2712     77.83        90         100
# 4         Vaini -21.2000 -175.2000     86.16        79          75
# 5        Albany  42.6001  -73.9662     21.81        64           7
# 6         Sitka  57.0531 -135.3300     35.49        80          75
# 7     Jamestown  42.0970  -79.2353     29.84        50           0
# 8       Mataura -46.1927  168.8643     75.47        50          69
# 9  Beringovskiy  63.0500  179.3167      6.24        82          96
#
#    Wind Speed Weather Right Now Country                 Date
# 0        9.24     broken clouds      IL  2022-01-31 23:38:57
# 1        3.78     broken clouds      PF  2022-01-31 23:40:00
# 2        8.32     broken clouds      AR  2022-01-31 23:37:48
# 3       10.31   overcast clouds      PG  2022-01-31 23:41:57
# 4       10.36     broken clouds      TO  2022-01-31 23:41:57
# 5        1.92         clear sky      US  2022-01-31 23:37:49
# 6        3.44     broken clouds      US  2022-01-31 23:39:39
# 7        5.75         clear sky      US  2022-01-31 23:40:52
# 8        2.42     broken clouds      NZ  2022-01-31 23:41:58
# 9       17.58        light snow      RU  2022-01-31 23:41:08

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
